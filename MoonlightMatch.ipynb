# %% [markdown]
# # Read Data from Google Sheet

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
import pandas as pd

# Replace this with your downloaded JSON credentials file path
SERVICE_ACCOUNT_FILE = 'refreshing-park-454420-u2-55ad31703fbb.json'

# Replace this with your Google Sheet ID from the URL
SPREADSHEET_ID = '1Cz8HyMIBeDZUN_uLQ-TrFTc1eaNO29qLNXr4vg5FGq0'

# Adjust if your data is not in 'Sheet1' or if you need a specific range
RANGE_NAME = 'Răspunsuri la formular 1!A:Z'

credentials = service_account.Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=['https://www.googleapis.com/auth/spreadsheets.readonly'])

service = build('sheets', 'v4', credentials=credentials)

# Get data from your sheet
sheet = service.spreadsheets()
result = sheet.values().get(spreadsheetId=SPREADSHEET_ID, range=RANGE_NAME).execute()
values = result.get('values', [])

if not values:
    print('No data found in your Google Sheet.')
else:
    df = pd.DataFrame(values[1:], columns=values[0])
    print(df.head())
# Out:
#         Marcaj de timp      What is your name? How old are you?  \
# 0  20.03.2025 13:29:18  George-Alexandru Marin               22
# 1  20.03.2025 13:29:58                Mariana                21
# 2  20.03.2025 13:30:47              Tzio Mping               26
# 3  20.03.2025 13:31:24                  Andrei               21
# 4  20.03.2025 13:33:50                    Ella               24
#
#   How tall are you? What is your occupation?  \
# 0      170 - 175 cm                       IT
# 1      170 - 175 cm                 Student
# 2      180 - 185 cm        Digital Marketing
# 3      195 - 200 cm                  student
# 4      175 - 180 cm             Antreprenor
#
#   What are your main hobbies or interests? (Select all that apply)  \
# 0                Gym, Sports, Cooking/Baking, Gaming
# 1  Hiking, Tv shows/Movies, Music/Art, Socializin...
# 2  Traveling, Gaming, Gym, Cooking/Baking, Cars/M...
# 3                  Socializing, Music/Art, Traveling
# 4   Reading, Socializing, Cars/Motorbikes, Traveling
#
#      Do you have any pets?  \
# 0             Yes – Cat(s)
# 1             Yes – Cat(s)
# 2  No, but I would love to
# 3  No, but I would love to
# 4             Yes – Dog(s)
#
#   What is your favorite music genre? (Select all that apply)  \
# 0     Pop, Rock, Hip-Hop/Rap, Jazz/Blues, Electronic
# 1                                  Pop, Rock, Manele
# 2                                Hip-Hop/Rap, Manele
# 3                                                r&b
# 4                             Pop, Rock, Hip-Hop/Rap
#
#   Who is your favorite band or artist?  \
# 0
# 1                                Adele
# 2                Bogdan De La Ploiesti
# 3                             beyonce
# 4                              Beyonce
#
#   What type of movie or TV show do you prefer? (Select all that apply)  ...  \
# 0            Drama, Science Fiction/Fantasy, Romance                    ...
# 1                  Action/Adventure, Comedy, Romance                    ...
# 2                           Action/Adventure, Comedy                    ...
# 3                            Comedy, Horror/Thriller                    ...
# 4                                        Documentary                    ...
#
#   Which of these are on your bucket list? (Select all that apply)  \
# 0        Running a marathon, Learning a new language
# 1  Running a marathon, Learning a new language, S...
# 2  Traveling to a new continent, Skydiving or bun...
# 3  Traveling to a new continent, Skydiving or bun...
# 4  Traveling to a new continent, Learning a new l...
#
#   Which of the following vices would you say you have? (Select all that apply):  \
# 0                                  None of the above
# 1                                  None of the above
# 2                                           Gambling
# 3               Smoking, Regular alcohol consumption
# 4                                            Smoking
#
#   Which gender do you prefer for your ideal partner? (Select all that apply)  \
# 0                                             Female
# 1                                               Male
# 2                                             Female
# 3                                               Male
# 4                                               Male
#
#   What physical attributes are most attractive to you in a partner? (Select all that apply)  \
# 0                               No strong preference
# 1         Tall, Athletic build, Stylish/Well-groomed
# 2                                       Natural look
# 3         Tall, Athletic build, Stylish/Well-groomed
# 4                               Tall, Athletic build
#
#   What age range do you prefer?  \
# 0                         18–25
# 1                         26–35
# 2                         18–25
# 3                         18–25
# 4                         26–35
#
#   Which best describes your preferred activity level for a partner?  \
# 0                               Highly active/Sporty
# 1                               Highly active/Sporty
# 2                               Highly active/Sporty
# 3                                  Moderately active
# 4                               Highly active/Sporty
#
#   How important is it that your partner is pet-friendly?  \
# 0                                                  5
# 1                                                  3
# 2                                                  3
# 3                                                  5
# 4                                                  4
#
#   How important is it that your partner is child-friendly?  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  3
#
#   Which of these traits would be deal breakers for you? (Select all that apply)  \
# 0  Excessive drinking, Lack of ambition, Poor hyg...
# 1  Excessive drinking, Lack of ambition, Poor hyg...
# 2                              Smoking, Poor hygiene
# 3  Lack of ambition, Disrespectful behavior, ange...
# 4  Smoking, Excessive drinking, Lack of ambition,...
#
#   What is your gender?
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4               Female
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#              Marcaj de timp What is your name? How old are you?  \
# count                   519                519              519
# unique                  518                518               32
# top     20.03.2025 13:37:46      Matthew Evans               30
# freq                      2                  2               25
#
#        How tall are you? What is your occupation?  \
# count                519                      519
# unique                11                       22
# top              200+ cm               Healthcare
# freq                  55                       70
#
#        What are your main hobbies or interests? (Select all that apply)  \
# count                                                 519
# unique                                                394
# top                                                Sports
# freq                                                   13
#
#           Do you have any pets?  \
# count                       519
# unique                        6
# top     No, but I would love to
# freq                         94
#
#        What is your favorite music genre? (Select all that apply)  \
# count                                                 519
# unique                                                162
# top                                                Manele
# freq                                                   27
#
#        Who is your favorite band or artist?  \
# count                                   519
# unique                                  511
# top
# freq                                      7
#
#        What type of movie or TV show do you prefer? (Select all that apply)  \
# count                                                 519
# unique                                                133
# top                                       Horror/Thriller
# freq                                                   34
#
#         ... Which of these are on your bucket list? (Select all that apply)  \
# count   ...                                                519
# unique  ...                                                 88
# top     ...                       Traveling to a new continent
# freq    ...                                                 41
#
#        Which of the following vices would you say you have? (Select all that apply):  \
# count                                                 519
# unique                                                 25
# top                                               Smoking
# freq                                                   60
#
#        Which gender do you prefer for your ideal partner? (Select all that apply)  \
# count                                                 519
# unique                                                  4
# top                                                  Male
# freq                                                  137
#
#        What physical attributes are most attractive to you in a partner? (Select all that apply)  \
# count                                                 519
# unique                                                 30
# top                                  Stylish/Well-groomed
# freq                                                   61
#
#        What age range do you prefer?  \
# count                            519
# unique                             5
# top                            18–25
# freq                             119
#
#        Which best describes your preferred activity level for a partner?  \
# count                                                 519
# unique                                                  4
# top                                     Moderately active
# freq                                                  154
#
#        How important is it that your partner is pet-friendly?  \
# count                                                 519
# unique                                                  5
# top                                                     1
# freq                                                  115
#
#        How important is it that your partner is child-friendly?  \
# count                                                 519
# unique                                                  5
# top                                                     3
# freq                                                  129
#
#        Which of these traits would be deal breakers for you? (Select all that apply)  \
# count                                                 519
# unique                                                131
# top                                          Poor hygiene
# freq                                                   39
#
#        What is your gender?
# count                   515
# unique                    4
# top                  Female
# freq                    134
#
# [4 rows x 24 columns]

# %%
# Print the hole data
print(df)
# Out:
#           Marcaj de timp      What is your name? How old are you?  \
# 0    20.03.2025 13:29:18  George-Alexandru Marin               22
# 1    20.03.2025 13:29:58                Mariana                21
# 2    20.03.2025 13:30:47              Tzio Mping               26
# 3    20.03.2025 13:31:24                  Andrei               21
# 4    20.03.2025 13:33:50                    Ella               24
# ..                   ...                     ...              ...
# 511  20.03.2025 14:02:31      Emily Rodriguez MD               38
# 512  20.03.2025 14:02:34            Kevin Steele               42
# 513  20.03.2025 14:02:37           Kristi Romero               24
# 514  20.03.2025 14:02:40           Natalie Smith               24
# 515  20.03.2025 14:02:43             Alan Kelley               38
#
#     How tall are you? What is your occupation?  \
# 0        170 - 175 cm                       IT
# 1        170 - 175 cm                 Student
# 2        180 - 185 cm        Digital Marketing
# 3        195 - 200 cm                  student
# 4        175 - 180 cm             Antreprenor
# ..                ...                      ...
# 511      190 - 195 cm                  Teacher
# 512      150 - 155 cm                    Other
# 513      165 - 170 cm                 Engineer
# 514           200+ cm          IT Professional
# 515      190 - 195 cm                   Artist
#
#     What are your main hobbies or interests? (Select all that apply)  \
# 0                  Gym, Sports, Cooking/Baking, Gaming
# 1    Hiking, Tv shows/Movies, Music/Art, Socializin...
# 2    Traveling, Gaming, Gym, Cooking/Baking, Cars/M...
# 3                    Socializing, Music/Art, Traveling
# 4     Reading, Socializing, Cars/Motorbikes, Traveling
# ..                                                 ...
# 511  Reading, Gaming, Playing musical instruments, ...
# 512                                          Music/Art
# 513                         Traveling, Tv shows/Movies
# 514                                     Cooking/Baking
# 515                                       Gym, Reading
#
#        Do you have any pets?  \
# 0               Yes – Cat(s)
# 1               Yes – Cat(s)
# 2    No, but I would love to
# 3    No, but I would love to
# 4               Yes – Dog(s)
# ..                       ...
# 511       Yes – Other pet(s)
# 512                       No
# 513             Yes – Dog(s)
# 514  No, but I would love to
# 515             Yes – Dog(s)
#
#     What is your favorite music genre? (Select all that apply)  \
# 0       Pop, Rock, Hip-Hop/Rap, Jazz/Blues, Electronic
# 1                                    Pop, Rock, Manele
# 2                                  Hip-Hop/Rap, Manele
# 3                                                  r&b
# 4                               Pop, Rock, Hip-Hop/Rap
# ..                                                 ...
# 511                                                Pop
# 512                                                Pop
# 513                            Hip-Hop/Rap, Electronic
# 514                                 Manele, Electronic
# 515                                     Pop, Classical
#
#     Who is your favorite band or artist?  \
# 0
# 1                                  Adele
# 2                  Bogdan De La Ploiesti
# 3                               beyonce
# 4                                Beyonce
# ..                                   ...
# 511                     Margaret Schmitt
# 512                          Cindy Brown
# 513                           Lisa Wiley
# 514                   Christopher Walker
# 515                           Carrie Lin
#
#     What type of movie or TV show do you prefer? (Select all that apply)  ...  \
# 0              Drama, Science Fiction/Fantasy, Romance                    ...
# 1                    Action/Adventure, Comedy, Romance                    ...
# 2                             Action/Adventure, Comedy                    ...
# 3                              Comedy, Horror/Thriller                    ...
# 4                                          Documentary                    ...
# ..                                                 ...                    ...
# 511                                            Romance                    ...
# 512                   Drama, Action/Adventure, Romance                    ...
# 513                          Action/Adventure, Romance                    ...
# 514  Action/Adventure, Comedy, Science Fiction/Fantasy                    ...
# 515           Science Fiction/Fantasy, Comedy, Romance                    ...
#
#     Which of these are on your bucket list? (Select all that apply)  \
# 0          Running a marathon, Learning a new language
# 1    Running a marathon, Learning a new language, S...
# 2    Traveling to a new continent, Skydiving or bun...
# 3    Traveling to a new continent, Skydiving or bun...
# 4    Traveling to a new continent, Learning a new l...
# ..                                                 ...
# 511                       Traveling to a new continent
# 512   Running a marathon, Traveling to a new continent
# 513  Learning a new language, Running a marathon, S...
# 514  Starting your own business, Traveling to a new...
# 515        Running a marathon, Learning a new language
#
#     Which of the following vices would you say you have? (Select all that apply):  \
# 0                                    None of the above
# 1                                    None of the above
# 2                                             Gambling
# 3                 Smoking, Regular alcohol consumption
# 4                                              Smoking
# ..                                                 ...
# 511                                            Smoking
# 512                                           Gambling
# 513                                  None of the above
# 514              Regular alcohol consumption, Gambling
# 515                        Regular alcohol consumption
#
#     Which gender do you prefer for your ideal partner? (Select all that apply)  \
# 0                                               Female
# 1                                                 Male
# 2                                               Female
# 3                                                 Male
# 4                                                 Male
# ..                                                 ...
# 511                                             Female
# 512                                               Male
# 513                                  Prefer not to say
# 514                                  It doesn't matter
# 515                                             Female
#
#     What physical attributes are most attractive to you in a partner? (Select all that apply)  \
# 0                                 No strong preference
# 1           Tall, Athletic build, Stylish/Well-groomed
# 2                                         Natural look
# 3           Tall, Athletic build, Stylish/Well-groomed
# 4                                 Tall, Athletic build
# ..                                                 ...
# 511                 Stylish/Well-groomed, Natural look
# 512                               No strong preference
# 513                                       Natural look
# 514                 No strong preference, Natural look
# 515                                               Tall
#
#     What age range do you prefer?  \
# 0                           18–25
# 1                           26–35
# 2                           18–25
# 3                           18–25
# 4                           26–35
# ..                            ...
# 511                         26–35
# 512                           46+
# 513                         36–45
# 514                         18–25
# 515                 No preference
#
#     Which best describes your preferred activity level for a partner?  \
# 0                                 Highly active/Sporty
# 1                                 Highly active/Sporty
# 2                                 Highly active/Sporty
# 3                                    Moderately active
# 4                                 Highly active/Sporty
# ..                                                 ...
# 511                               Highly active/Sporty
# 512                                      No preference
# 513                               Highly active/Sporty
# 514                               Highly active/Sporty
# 515                                    Not very active
#
#     How important is it that your partner is pet-friendly?  \
# 0                                                    5
# 1                                                    3
# 2                                                    3
# 3                                                    5
# 4                                                    4
# ..                                                 ...
# 511                                                  5
# 512                                                  2
# 513                                                  3
# 514                                                  3
# 515                                                  5
#
#     How important is it that your partner is child-friendly?  \
# 0                                                    5
# 1                                                    5
# 2                                                    4
# 3                                                    5
# 4                                                    3
# ..                                                 ...
# 511                                                  2
# 512                                                  4
# 513                                                  5
# 514                                                  3
# 515                                                  2
#
#     Which of these traits would be deal breakers for you? (Select all that apply)  \
# 0    Excessive drinking, Lack of ambition, Poor hyg...
# 1    Excessive drinking, Lack of ambition, Poor hyg...
# 2                                Smoking, Poor hygiene
# 3    Lack of ambition, Disrespectful behavior, ange...
# 4    Smoking, Excessive drinking, Lack of ambition,...
# ..                                                 ...
# 511  Excessive drinking, Disrespectful behavior, No...
# 512                None of the above, Lack of ambition
# 513                        Smoking, Excessive drinking
# 514                        Smoking, Excessive drinking
# 515                             Disrespectful behavior
#
#     What is your gender?
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                 Female
# ..                   ...
# 511           Non-binary
# 512               Female
# 513                 Male
# 514               Female
# 515    Prefer not to say
#
# [516 rows x 24 columns]

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Incarci modelul pretrained Sentence Transformer
model = SentenceTransformer('all-MiniLM-L6-v2')

# Citesti datele din Google Sheets (ai facut deja asta anterior)
# presupunand ca ai deja dataframe-ul df incarcat:
# df = pd.read_csv('your-google-sheet-export.csv') 
# sau cu Google Sheets API cum ai implementat anterior

# Exemplu concret cu două persoane (din dataframe-ul tau df)
user_1 = df.iloc[0]  # Prima persoana (randul 0)
user_2 = df.iloc[1]  # A doua persoana (randul 1)

# Lista de coloane relevante pentru matching (personalizeaza conform formularului tau)
matching_columns = [
    "What are your main hobbies or interests? (Select all that apply)", "What is your occupation?",
    "Do you have any pets?", "What is your favorite music genre? (Select all that apply)",
    "What type of movie or TV show do you prefer? (Select all that apply)",
    "What type of physical activity do you prefer? (Select all that apply)",
    "Which type of vacation do you prefer? (Select all that apply)", "Which of these are on your bucket list? (Select all that apply)",
    "Which of the following vices would you say you have? (Select all that apply):"
]

# Functie pentru calculul similaritatii între doi utilizatori
def calculate_similarity(user_a, user_b, columns, model):
    scores = []
    for column in columns:
        response_a = str(user_a[column])
        preference_b = str(user_b[column])

        # Creezi embedding-uri pentru fiecare pereche întrebare-răspuns
        embeddings = model.encode([response_a, preference_b])

        # Calculezi similaritatea cosine
        sim = cosine_similarity([embeddings[0]], [embeddings[1]])[0][0]
        scores.append(sim)

    # Similaritatea medie pe toate intrebarile
    average_similarity = np.mean(scores)
    return average_similarity

# Calculeaza similaritatea
similarity_score = calculate_similarity(user_1, user_2, matching_columns, model)

# Afiseaza scorul obtinut
print(f"Compatibility Score between '{user_1['What is your name?']}' and '{user_2['What is your name?']}': {similarity_score:.3f}")
# Out:
# Compatibility Score between 'George-Alexandru Marin' and 'Mariana ': 0.724

# %%
# Numarul total de utilizatori
num_users = len(df)

# Matrice pentru scorurile de similaritate
similarity_matrix = np.zeros((num_users, num_users))

for i in range(num_users):
    for j in range(num_users):
        if i != j:
            similarity_matrix[i, j] = calculate_similarity(df.iloc[i], df.iloc[j], matching_columns, model)

# Transformă matricea în DataFrame pentru ușurință de vizualizare
similarity_df = pd.DataFrame(similarity_matrix, columns=df['What is your name?'], index=df['What is your name?'])

# Afiseaza primele 5 randuri
print(similarity_df.head())
# Out:
# What is your name?      George-Alexandru Marin  Mariana   Tzio Mping  \
# What is your name?
# George-Alexandru Marin                0.000000  0.724466    0.495795
# Mariana                               0.724466  0.000000    0.496185
# Tzio Mping                            0.495795  0.496185    0.000000
# Andrei                                0.355407  0.481997    0.570429
# Ella                                  0.561062  0.486539    0.486007
#
# What is your name?        Andrei      Ella  Cavescu Dumitru  Ana Lipianu  \
# What is your name?
# George-Alexandru Marin  0.355407  0.561062         0.661822     0.453462
# Mariana                 0.481997  0.486539         0.679739     0.554207
# Tzio Mping              0.570429  0.486007         0.673404     0.563575
# Andrei                  0.000000  0.409740         0.549936     0.607871
# Ella                    0.409740  0.000000         0.477127     0.392282
#
# What is your name?      Chandler Bing  Cojocaru Andrei Radu   Mandru Luca   \
# What is your name?
# George-Alexandru Marin       0.367363               0.549841      0.556852
# Mariana                      0.384773               0.616811      0.631535
# Tzio Mping                   0.429275               0.499163      0.583466
# Andrei                       0.519688               0.520127      0.590901
# Ella                         0.468419               0.391061      0.456356
#
# What is your name?      ...  Nicholas Myers  Dr. Robert Myers  Nancy Hebert  \
# What is your name?      ...
# George-Alexandru Marin  ...        0.601272          0.422612      0.503607
# Mariana                 ...        0.507183          0.441335      0.513582
# Tzio Mping              ...        0.575026          0.689246      0.641402
# Andrei                  ...        0.421979          0.488611      0.477918
# Ella                    ...        0.474720          0.446972      0.522100
#
# What is your name?      Susan Moyer  Earl Davis  Emily Rodriguez MD  \
# What is your name?
# George-Alexandru Marin     0.386933    0.570923            0.504738
# Mariana                    0.446452    0.623300            0.561890
# Tzio Mping                 0.446213    0.581805            0.439735
# Andrei                     0.522823    0.575067            0.504328
# Ella                       0.379187    0.556763            0.574706
#
# What is your name?      Kevin Steele  Kristi Romero  Natalie Smith  \
# What is your name?
# George-Alexandru Marin      0.443380       0.644820       0.425088
# Mariana                     0.480719       0.646906       0.389407
# Tzio Mping                  0.538775       0.500961       0.567391
# Andrei                      0.402921       0.429370       0.582051
# Ella                        0.394433       0.543214       0.358357
#
# What is your name?      Alan Kelley
# What is your name?
# George-Alexandru Marin     0.611682
# Mariana                    0.491253
# Tzio Mping                 0.407085
# Andrei                     0.459798
# Ella                       0.528138
#
# [5 rows x 516 columns]

# %%
# Afiseaza cel mai compatibil utilizator pentru fiecare persoana
for i in range(num_users):
    user_name = df.iloc[i]['What is your name?']
    most_compatible_user = similarity_df[user_name].idxmax()
    compatibility_score = similarity_df[user_name].max()
    print(f"Most compatible user for '{user_name}': '{most_compatible_user}' with a compatibility score of {compatibility_score:.3f}")
# Out:
# Most compatible user for 'George-Alexandru Marin': 'Katherine Owens' with a compatibility score of 0.747
# Most compatible user for 'Mariana ': 'Gregory Williams' with a compatibility score of 0.727
# Most compatible user for 'Tzio Mping': 'Nancy Roberts' with a compatibility score of 0.760
# Most compatible user for 'Andrei': 'Alexis Cook' with a compatibility score of 0.705
# Most compatible user for 'Ella': 'Denise Smith' with a compatibility score of 0.654
# Most compatible user for 'Cavescu Dumitru': 'Cojocaru Andrei Radu ' with a compatibility score of 0.739
# Most compatible user for 'Ana Lipianu': 'Thomas Carr' with a compatibility score of 0.690
# Most compatible user for 'Chandler Bing': 'Jason Jennings' with a compatibility score of 0.717
# Most compatible user for 'Cojocaru Andrei Radu ': 'Cavescu Dumitru' with a compatibility score of 0.739
# Most compatible user for 'Mandru Luca ': 'Tony Grimes' with a compatibility score of 0.776
# Most compatible user for 'Monica Geller': 'Bonnie Werner' with a compatibility score of 0.741
# Most compatible user for 'Ross Geller': 'Crystal Washington' with a compatibility score of 0.730
# Most compatible user for 'Rachel Green': 'Robert Foster' with a compatibility score of 0.679
# Most compatible user for 'Joey Tribianni': 'Tony Grimes' with a compatibility score of 0.791
# Most compatible user for 'Phoebe Buffae': 'Maria Valdez' with a compatibility score of 0.726
# Most compatible user for 'Alia Andrei': 'Sean Jackson' with a compatibility score of 0.742
# Most compatible user for 'Maria Bentley': 'Adam Rhodes' with a compatibility score of 0.677
# Most compatible user for 'Jeffery Blake': 'Erica Espinoza' with a compatibility score of 0.759
# Most compatible user for 'Mr. Jeremy Evans': 'Dale Snyder' with a compatibility score of 0.711
# Most compatible user for 'Hannah Ross': 'Mary Potts' with a compatibility score of 0.737
# Most compatible user for 'Stephanie Jackson': 'Michelle Miller' with a compatibility score of 0.758
# Most compatible user for 'Craig Chang': 'Kevin Gray' with a compatibility score of 0.738
# Most compatible user for 'Ann Haynes': 'Kimberly Avery' with a compatibility score of 0.738
# Most compatible user for 'Ian Wilson': 'Mary Potts' with a compatibility score of 0.792
# Most compatible user for 'Keith Moore': 'Natalie Wells' with a compatibility score of 0.749
# Most compatible user for 'Maria Nash': 'Laurie Rice' with a compatibility score of 0.712
# Most compatible user for 'Edward Brock': 'Miranda Delacruz' with a compatibility score of 0.762
# Most compatible user for 'Jonathan Montgomery': 'Deborah Flores' with a compatibility score of 0.747
# Most compatible user for 'Jamie Nicholson': 'Andrew Cross' with a compatibility score of 0.667
# Most compatible user for 'Bill Barnes': 'Amber Freeman' with a compatibility score of 0.753
# Most compatible user for 'Michael Richmond': 'Sharon Mills' with a compatibility score of 0.764
# Most compatible user for 'Alexander Willis': 'Traci Washington' with a compatibility score of 0.666
# Most compatible user for 'Denise Barker': 'Bonnie Sutton' with a compatibility score of 0.754
# Most compatible user for 'Richard Jones': 'Nicholas Myers' with a compatibility score of 0.746
# Most compatible user for 'Carlos Oliver': 'Hunter Cummings' with a compatibility score of 0.636
# Most compatible user for 'Mr. Travis Walters': 'Molly Graham' with a compatibility score of 0.694
# Most compatible user for 'Rebecca Watts': 'Alia Andrei' with a compatibility score of 0.702
# Most compatible user for 'Stephen Fields': 'Earl Davis' with a compatibility score of 0.712
# Most compatible user for 'Kyle Green': 'Carla White' with a compatibility score of 0.735
# Most compatible user for 'Cynthia Hurley': 'Paul Cohen' with a compatibility score of 0.740
# Most compatible user for 'Willie Crawford': 'Anthony Richardson' with a compatibility score of 0.836
# Most compatible user for 'Timothy Davis': 'Sara Jenkins' with a compatibility score of 0.705
# Most compatible user for 'Michelle Gray': 'Amanda Holt' with a compatibility score of 0.691
# Most compatible user for 'Anthony Fleming': 'Bryan Walsh' with a compatibility score of 0.704
# Most compatible user for 'Jacob Smith': 'Daniel Mccann' with a compatibility score of 0.676
# Most compatible user for 'Sherri Walters': 'Bryan Walsh' with a compatibility score of 0.831
# Most compatible user for 'Michael Patterson': 'Louis Perez' with a compatibility score of 0.755
# Most compatible user for 'Kristy Zamora': 'Jason Jennings' with a compatibility score of 0.692
# Most compatible user for 'Carl Webb': 'John Nicholson' with a compatibility score of 0.748
# Most compatible user for 'Jeremy Ballard': 'Scott Hanson' with a compatibility score of 0.774
# Most compatible user for 'Joshua Gutierrez': 'Christine Johnson' with a compatibility score of 0.708
# Most compatible user for 'Megan Nunez': 'Sarah Hoffman' with a compatibility score of 0.715
# Most compatible user for 'Donna Evans': 'Lori Marshall' with a compatibility score of 0.676
# Most compatible user for 'Maria Martin': 'Melissa Price' with a compatibility score of 0.713
# Most compatible user for 'Joseph Hamilton': 'Amy Rogers' with a compatibility score of 0.709
# Most compatible user for 'Jerry Davis': 'Erika Morgan' with a compatibility score of 0.763
# Most compatible user for 'Mark Sullivan': 'Hannah Wang' with a compatibility score of 0.731
# Most compatible user for 'Tammy Chan': 'Pamela Proctor' with a compatibility score of 0.718
# Most compatible user for 'Jason Serrano': 'Paul Cohen' with a compatibility score of 0.730
# Most compatible user for 'Lynn Cummings': 'Manuel Alvarez' with a compatibility score of 0.801
# Most compatible user for 'John Sullivan': 'Andrea Davidson' with a compatibility score of 0.703
# Most compatible user for 'Anna Schroeder': 'Robert Rodriguez' with a compatibility score of 0.772
# Most compatible user for 'Michael Powell': 'Ms. Stephanie Carroll' with a compatibility score of 0.754
# Most compatible user for 'Melissa Hill': 'Nathaniel Davis' with a compatibility score of 0.730
# Most compatible user for 'Jeffrey Wells': 'Ryan Atkinson' with a compatibility score of 0.743
# Most compatible user for 'Ashley Thomas': 'Desiree Wolf' with a compatibility score of 0.789
# Most compatible user for 'Dana Guzman': 'Michael Suarez' with a compatibility score of 0.698
# Most compatible user for 'Karen Brown': 'Cavescu Dumitru' with a compatibility score of 0.663
# Most compatible user for 'Sabrina Brown MD': 'Philip Green' with a compatibility score of 0.738
# Most compatible user for 'Carrie Hernandez': 'Carlos Day' with a compatibility score of 0.759
# Most compatible user for 'Destiny Wells': 'Brooke Jordan' with a compatibility score of 0.705
# Most compatible user for 'David Mcgee': 'Jose Jones' with a compatibility score of 0.766
# Most compatible user for 'Jeremy Williams': 'Scott Hanson' with a compatibility score of 0.790
# Most compatible user for 'James Ramirez': 'Daniel Shah' with a compatibility score of 0.709
# Most compatible user for 'Courtney Harper': 'Christopher Simmons' with a compatibility score of 0.708
# Most compatible user for 'Jennifer Cobb': 'Alec Bruce' with a compatibility score of 0.697
# Most compatible user for 'Matthew Cook': 'James Short' with a compatibility score of 0.751
# Most compatible user for 'Audrey Garcia MD': 'Maria Maldonado' with a compatibility score of 0.679
# Most compatible user for 'Katie Reed': 'Ryan Clark' with a compatibility score of 0.763
# Most compatible user for 'Stephen Kirby': 'Nancy Roberts' with a compatibility score of 0.714
# Most compatible user for 'Benjamin Reynolds': 'Lisa Perry' with a compatibility score of 0.700
# Most compatible user for 'Jasmine Finley': 'Caleb Weber' with a compatibility score of 0.703
# Most compatible user for 'Hannah Wang': 'Mark Sullivan' with a compatibility score of 0.731
# Most compatible user for 'William Hill': 'Corey Green' with a compatibility score of 0.688
# Most compatible user for 'Jose Foley': 'Nancy Hebert' with a compatibility score of 0.741
# Most compatible user for 'Heather Davidson': 'Deborah Flores' with a compatibility score of 0.777
# Most compatible user for 'James Price': 'Richard Wallace' with a compatibility score of 0.690
# Most compatible user for 'Claudia Chavez': 'Brooke Ward' with a compatibility score of 0.743
# Most compatible user for 'Dennis Russo': 'Robert Rodriguez' with a compatibility score of 0.693
# Most compatible user for 'Michelle Miller': 'Stephanie Jackson' with a compatibility score of 0.758
# Most compatible user for 'Carlos Day': 'Carrie Hernandez' with a compatibility score of 0.759
# Most compatible user for 'Amanda Peters': 'Joy Newman' with a compatibility score of 0.822
# Most compatible user for 'Kevin Bell': 'Natalie Smith' with a compatibility score of 0.698
# Most compatible user for 'Bryan Roberts': 'Ms. Stephanie Carroll' with a compatibility score of 0.828
# Most compatible user for 'Caleb Weber': 'Jasmine Finley' with a compatibility score of 0.703
# Most compatible user for 'Michael Bates': 'Earl Stewart' with a compatibility score of 0.843
# Most compatible user for 'Evelyn Rogers': 'Lisa Clark' with a compatibility score of 0.754
# Most compatible user for 'Jonathan Mcintyre': 'Michael Hayes' with a compatibility score of 0.730
# Most compatible user for 'Angela Marshall': 'Paul Cohen' with a compatibility score of 0.725
# Most compatible user for 'Karen Garcia': 'Cavescu Dumitru' with a compatibility score of 0.685
# Most compatible user for 'Bonnie Sutton': 'Denise Barker' with a compatibility score of 0.754
# Most compatible user for 'Vincent Mathis': 'James Barnett' with a compatibility score of 0.712
# Most compatible user for 'April Knight': 'Caitlin Williams' with a compatibility score of 0.718
# Most compatible user for 'Beth Rose': 'Willie Crawford' with a compatibility score of 0.745
# Most compatible user for 'Jeremy Jenkins Jr.': 'Matthew Rodriguez' with a compatibility score of 0.737
# Most compatible user for 'Christina Collins': 'Ian Wilson' with a compatibility score of 0.706
# Most compatible user for 'Ashley Boyd': 'Lisa Smith' with a compatibility score of 0.707
# Most compatible user for 'Ashley Delacruz': 'Rebecca Fleming' with a compatibility score of 0.753
# Most compatible user for 'Linda Mendoza': 'Carlos Cohen' with a compatibility score of 0.695
# Most compatible user for 'Dustin Baker': 'Christopher Ramirez' with a compatibility score of 0.743
# Most compatible user for 'Molly Smith': 'John Bailey' with a compatibility score of 0.692
# Most compatible user for 'Victor Brown': 'Elizabeth Drake' with a compatibility score of 0.758
# Most compatible user for 'Timothy Griffin': 'Andrew Fitzgerald' with a compatibility score of 0.797
# Most compatible user for 'Melanie Rivas': 'Scott Hanson' with a compatibility score of 0.759
# Most compatible user for 'Jordan Fisher': 'Donald Gomez' with a compatibility score of 0.789
# Most compatible user for 'Tiffany Lee': 'Frank Fisher' with a compatibility score of 0.701
# Most compatible user for 'Brian Marsh': 'Brandi Obrien' with a compatibility score of 0.705
# Most compatible user for 'Dale Snyder': 'Mr. Matthew Bennett' with a compatibility score of 0.715
# Most compatible user for 'Albert Marshall': 'Jon Butler' with a compatibility score of 0.681
# Most compatible user for 'Erika Morgan': 'Helen Robles' with a compatibility score of 0.790
# Most compatible user for 'Erica Espinoza': 'Jeffery Blake' with a compatibility score of 0.759
# Most compatible user for 'Sara Jenkins': 'Timothy Davis' with a compatibility score of 0.705
# Most compatible user for 'Steven Schaefer': 'Nancy Wu' with a compatibility score of 0.678
# Most compatible user for 'Michael Hayes': 'Jonathan Mcintyre' with a compatibility score of 0.730
# Most compatible user for 'Steven Schwartz': 'Mary Dennis' with a compatibility score of 0.719
# Most compatible user for 'Kurt Parker': 'Dana Rodriguez' with a compatibility score of 0.798
# Most compatible user for 'Tonya Miller': 'Kelly Joseph' with a compatibility score of 0.740
# Most compatible user for 'Brittany Wells': 'Roger Bennett' with a compatibility score of 0.755
# Most compatible user for 'Roger Bennett': 'Brittany Wells' with a compatibility score of 0.755
# Most compatible user for 'James Short': 'Matthew Cook' with a compatibility score of 0.751
# Most compatible user for 'James Ryan': 'Claudia Chavez' with a compatibility score of 0.706
# Most compatible user for 'Kristen Miller': 'Matthew Evans' with a compatibility score of 0.769
# Most compatible user for 'Steven Cooper': 'Deborah French' with a compatibility score of 0.739
# Most compatible user for 'Pamela Proctor': 'Ryan Clark' with a compatibility score of 0.774
# Most compatible user for 'Scott Hanson': 'Jeremy Williams' with a compatibility score of 0.790
# Most compatible user for 'Terry Evans': 'Vanessa Ward' with a compatibility score of 0.778
# Most compatible user for 'Kelly Turner': 'Kim Thompson' with a compatibility score of 0.728
# Most compatible user for 'Robert Foster': 'Nancy Hebert' with a compatibility score of 0.730
# Most compatible user for 'Mark Pineda': 'Dustin Baker' with a compatibility score of 0.725
# Most compatible user for 'Jake Carson': 'Caleb Thompson' with a compatibility score of 0.715
# Most compatible user for 'Dennis Lopez': 'Courtney Velasquez' with a compatibility score of 0.753
# Most compatible user for 'Ellen Riley': 'Felicia Jones' with a compatibility score of 0.708
# Most compatible user for 'Caitlin Adams': 'Ellen Riley' with a compatibility score of 0.705
# Most compatible user for 'Maria Valdez': 'Phoebe Buffae' with a compatibility score of 0.726
# Most compatible user for 'Angela Robinson': 'Anthony Jones' with a compatibility score of 0.693
# Most compatible user for 'Matthew Johnson': 'Alec Bruce' with a compatibility score of 0.745
# Most compatible user for 'Helen Robles': 'Erika Morgan' with a compatibility score of 0.790
# Most compatible user for 'Mark Golden': 'Mr. Joshua Garrison' with a compatibility score of 0.724
# Most compatible user for 'Omar Pierce': 'Bryan Roberts' with a compatibility score of 0.704
# Most compatible user for 'Jennifer Baker': 'Felicia Jones' with a compatibility score of 0.710
# Most compatible user for 'Kevin Lee': 'Brooke Ford' with a compatibility score of 0.711
# Most compatible user for 'Kelly Joseph': 'Tonya Miller' with a compatibility score of 0.740
# Most compatible user for 'William Holland': 'Amy Jennings' with a compatibility score of 0.742
# Most compatible user for 'Crystal Rivera': 'Christopher Morrison' with a compatibility score of 0.762
# Most compatible user for 'Dr. Karen Garcia': 'Jeremy Manning' with a compatibility score of 0.719
# Most compatible user for 'Chris Hernandez': 'Carlos Cohen' with a compatibility score of 0.647
# Most compatible user for 'Henry Holt': 'Elizabeth Sanchez' with a compatibility score of 0.724
# Most compatible user for 'Beth Thomas': 'Carol Monroe' with a compatibility score of 0.725
# Most compatible user for 'Carlos Cohen': 'Katie Reed' with a compatibility score of 0.735
# Most compatible user for 'Caroline Hunter': 'Melissa Roth' with a compatibility score of 0.692
# Most compatible user for 'Jason Jennings': 'Chandler Bing' with a compatibility score of 0.717
# Most compatible user for 'Stephanie Dennis': 'Jeffrey Wilkerson' with a compatibility score of 0.722
# Most compatible user for 'David Hanna': 'James Short' with a compatibility score of 0.733
# Most compatible user for 'Brenda Miller': 'Richard Burton' with a compatibility score of 0.763
# Most compatible user for 'Lisa Perry': 'Rebekah Hayes' with a compatibility score of 0.754
# Most compatible user for 'Eric Carroll': 'Carl Webb' with a compatibility score of 0.721
# Most compatible user for 'Louis Perez': 'Ryan Clark' with a compatibility score of 0.759
# Most compatible user for 'Adam Rhodes': 'Mark Sullivan' with a compatibility score of 0.720
# Most compatible user for 'David Brown': 'Ryan Atkinson' with a compatibility score of 0.769
# Most compatible user for 'Jamie Perkins': 'Keith Moore' with a compatibility score of 0.716
# Most compatible user for 'Carla White': 'Dr. Dominic Fernandez DVM' with a compatibility score of 0.740
# Most compatible user for 'Robert Johnson': 'Richard Wallace' with a compatibility score of 0.702
# Most compatible user for 'Sandra Miller': 'William Hill' with a compatibility score of 0.667
# Most compatible user for 'Caleb Thompson': 'Jake Carson' with a compatibility score of 0.715
# Most compatible user for 'Ian Simon': 'Kathy Perry' with a compatibility score of 0.797
# Most compatible user for 'Brendan Robinson': 'Laurie Garcia' with a compatibility score of 0.748
# Most compatible user for 'Jerry Hill': 'James Ramirez' with a compatibility score of 0.692
# Most compatible user for 'Rose Villegas': 'Jeffrey Bradley' with a compatibility score of 0.735
# Most compatible user for 'Lindsey Mitchell': 'James Short' with a compatibility score of 0.707
# Most compatible user for 'Matthew Fuentes': 'Emily Rodriguez MD' with a compatibility score of 0.771
# Most compatible user for 'Lynn Roman': 'Deborah Flores' with a compatibility score of 0.735
# Most compatible user for 'Jonathan Mitchell': 'David Washington' with a compatibility score of 0.806
# Most compatible user for 'Jessica Walker': 'Emma Austin' with a compatibility score of 0.670
# Most compatible user for 'Kevin Gray': 'Michele Chavez' with a compatibility score of 0.774
# Most compatible user for 'Christopher Ramirez': 'Dustin Baker' with a compatibility score of 0.743
# Most compatible user for 'Brian Hodges': 'Laurie Rice' with a compatibility score of 0.747
# Most compatible user for 'Lisa Norman': 'Donna Martin' with a compatibility score of 0.743
# Most compatible user for 'John Butler': 'Robert Chapman' with a compatibility score of 0.676
# Most compatible user for 'Valerie Todd': 'Steven Schwartz' with a compatibility score of 0.707
# Most compatible user for 'Andrew Fitzgerald': 'Timothy Griffin' with a compatibility score of 0.797
# Most compatible user for 'Kimberly Avery': 'Ann Haynes' with a compatibility score of 0.738
# Most compatible user for 'Traci Washington': 'Juan Banks' with a compatibility score of 0.696
# Most compatible user for 'Carla Poole': 'Stephanie Walker' with a compatibility score of 0.761
# Most compatible user for 'Walter Wright': 'Sheri Briggs' with a compatibility score of 0.733
# Most compatible user for 'Bonnie Werner': 'Monica Geller' with a compatibility score of 0.741
# Most compatible user for 'Catherine Glenn': 'Sydney Harris' with a compatibility score of 0.792
# Most compatible user for 'Chelsea Woods': 'Carol Monroe' with a compatibility score of 0.725
# Most compatible user for 'Alec Bruce': 'Matthew Johnson' with a compatibility score of 0.745
# Most compatible user for 'Mr. Matthew Bennett': 'Kenneth Rocha' with a compatibility score of 0.757
# Most compatible user for 'Sean Jackson': 'Anthony Richardson' with a compatibility score of 0.772
# Most compatible user for 'Teresa Lane': 'Stacie Schultz' with a compatibility score of 0.710
# Most compatible user for 'John Allen': 'Jeffery Blake' with a compatibility score of 0.708
# Most compatible user for 'Jennifer Jackson': 'Robert Woodard' with a compatibility score of 0.802
# Most compatible user for 'Kenneth Jensen': 'Scott Hanson' with a compatibility score of 0.699
# Most compatible user for 'Nancy Roberts': 'Tzio Mping' with a compatibility score of 0.760
# Most compatible user for 'Anthony Richardson': 'Willie Crawford' with a compatibility score of 0.836
# Most compatible user for 'Gloria Meyers': 'Jon Butler' with a compatibility score of 0.712
# Most compatible user for 'Linda Sheppard': 'Matthew Lucero' with a compatibility score of 0.824
# Most compatible user for 'Mr. Joshua Garrison': 'Sue Weiss' with a compatibility score of 0.756
# Most compatible user for 'Austin Hancock': 'Nancy Roberts' with a compatibility score of 0.748
# Most compatible user for 'Sydney Ramirez': 'Raymond Coleman' with a compatibility score of 0.771
# Most compatible user for 'Sandra Buchanan': 'Steven Cooper' with a compatibility score of 0.736
# Most compatible user for 'Dana Rodriguez': 'Kurt Parker' with a compatibility score of 0.798
# Most compatible user for 'Philip Green': 'Sabrina Brown MD' with a compatibility score of 0.738
# Most compatible user for 'Angelica Velasquez': 'Matthew Rodriguez' with a compatibility score of 0.744
# Most compatible user for 'John Nicholson': 'Carl Webb' with a compatibility score of 0.748
# Most compatible user for 'Bryan Walsh': 'Sherri Walters' with a compatibility score of 0.831
# Most compatible user for 'Ricardo Kerr': 'Michael Powell' with a compatibility score of 0.729
# Most compatible user for 'Brian Rogers DVM': 'Joshua Hayes' with a compatibility score of 0.720
# Most compatible user for 'Lori Marshall': 'Mr. Joshua Garrison' with a compatibility score of 0.728
# Most compatible user for 'Jonathan Miller': 'Ian Simon' with a compatibility score of 0.729
# Most compatible user for 'Deborah French': 'Katherine Owens' with a compatibility score of 0.792
# Most compatible user for 'Manuel Alvarez': 'Lynn Cummings' with a compatibility score of 0.801
# Most compatible user for 'Jasmine Shaw': 'Emma Austin' with a compatibility score of 0.678
# Most compatible user for 'Brian Anderson': 'Austin Hancock' with a compatibility score of 0.717
# Most compatible user for 'Caitlyn Hoffman': 'Timothy Hammond' with a compatibility score of 0.778
# Most compatible user for 'Tracy Thompson': 'John Nicholson' with a compatibility score of 0.745
# Most compatible user for 'Brandon Patterson': 'Jenna Mitchell' with a compatibility score of 0.726
# Most compatible user for 'Amy Jennings': 'Erika Morgan' with a compatibility score of 0.762
# Most compatible user for 'Kyle Nunez': 'Julia Smith' with a compatibility score of 0.698
# Most compatible user for 'Christopher Morrison': 'Crystal Rivera' with a compatibility score of 0.762
# Most compatible user for 'Sarah Palmer': 'Amanda Peters' with a compatibility score of 0.759
# Most compatible user for 'Kathryn Taylor': 'Margaret Ray' with a compatibility score of 0.717
# Most compatible user for 'Pamela Hurst': 'Michael Butler' with a compatibility score of 0.675
# Most compatible user for 'Richard Reed': 'Jennifer Cooke' with a compatibility score of 0.760
# Most compatible user for 'Joseph Smith': 'Robert Gutierrez' with a compatibility score of 0.792
# Most compatible user for 'Hunter Cummings': 'Austin Hancock' with a compatibility score of 0.716
# Most compatible user for 'Danielle Ferrell': 'Donald Gomez' with a compatibility score of 0.701
# Most compatible user for 'Angela Price': 'Bonnie Werner' with a compatibility score of 0.664
# Most compatible user for 'Ryan Atkinson': 'David Brown' with a compatibility score of 0.769
# Most compatible user for 'Thomas Diaz': 'Valerie Rodriguez' with a compatibility score of 0.689
# Most compatible user for 'Ms. Stephanie Carroll': 'Bryan Roberts' with a compatibility score of 0.828
# Most compatible user for 'Alexander Page': 'Robert Brown' with a compatibility score of 0.722
# Most compatible user for 'Matthew Lucero': 'Linda Sheppard' with a compatibility score of 0.824
# Most compatible user for 'Cameron Walls': 'Carl Scott' with a compatibility score of 0.732
# Most compatible user for 'Dominic Green': 'Nicholas Myers' with a compatibility score of 0.707
# Most compatible user for 'Jesse Boone': 'Brendan Robinson' with a compatibility score of 0.742
# Most compatible user for 'Ashley Rice': 'Emily Mcpherson' with a compatibility score of 0.715
# Most compatible user for 'Anna Grant': 'Kurt Parker' with a compatibility score of 0.769
# Most compatible user for 'Tracy Marshall': 'Ronnie Blair' with a compatibility score of 0.743
# Most compatible user for 'Ronnie Blair': 'Tracy Marshall' with a compatibility score of 0.743
# Most compatible user for 'Susan Byrd': 'Kendra Sutton' with a compatibility score of 0.711
# Most compatible user for 'Wendy Cole': 'Anthony Jones' with a compatibility score of 0.747
# Most compatible user for 'Desiree Wolf': 'Ashley Thomas' with a compatibility score of 0.789
# Most compatible user for 'Taylor Hughes': 'Timothy Griffin' with a compatibility score of 0.747
# Most compatible user for 'Brandi Obrien': 'Brian Marsh' with a compatibility score of 0.705
# Most compatible user for 'Dale Cohen': 'Ashley Delacruz' with a compatibility score of 0.696
# Most compatible user for 'Rachel Thompson': 'Christine Nelson' with a compatibility score of 0.703
# Most compatible user for 'Jennifer Kim': 'Kyle Green' with a compatibility score of 0.666
# Most compatible user for 'John Bell': 'Matthew Bolton' with a compatibility score of 0.745
# Most compatible user for 'Taylor King': 'Latasha Patterson' with a compatibility score of 0.677
# Most compatible user for 'Juan Banks': 'Margaret Ray' with a compatibility score of 0.717
# Most compatible user for 'Ryan Clark': 'Pamela Proctor' with a compatibility score of 0.774
# Most compatible user for 'Jon Butler': 'Gloria Meyers' with a compatibility score of 0.712
# Most compatible user for 'Steven Gonzales': 'Beth Thomas' with a compatibility score of 0.713
# Most compatible user for 'Joshua Hayes': 'Brian Rogers DVM' with a compatibility score of 0.720
# Most compatible user for 'Kimberly Thomas': 'Jeremy Manning' with a compatibility score of 0.707
# Most compatible user for 'Nathaniel Davis': 'Melissa Hill' with a compatibility score of 0.730
# Most compatible user for 'Sue Weiss': 'Mr. Joshua Garrison' with a compatibility score of 0.756
# Most compatible user for 'Daniel Shah': 'Terry Evans' with a compatibility score of 0.774
# Most compatible user for 'Vanessa Ward': 'Terry Evans' with a compatibility score of 0.778
# Most compatible user for 'Christopher Wade': 'Donald Jones' with a compatibility score of 0.708
# Most compatible user for 'Brenda Morrow': 'Jonathan Mitchell' with a compatibility score of 0.704
# Most compatible user for 'Garrett Johnson': 'Hector Norton' with a compatibility score of 0.719
# Most compatible user for 'Kayla Beltran': 'Jaime Saunders' with a compatibility score of 0.757
# Most compatible user for 'Robert Rodriguez': 'Anna Schroeder' with a compatibility score of 0.772
# Most compatible user for 'Jeffrey Wilkerson': 'Carl Webb' with a compatibility score of 0.739
# Most compatible user for 'Elizabeth Sanchez': 'Daniel Dawson' with a compatibility score of 0.782
# Most compatible user for 'Christine Holmes': 'Deborah Flores' with a compatibility score of 0.747
# Most compatible user for 'Donald Chan': 'Melissa Patel' with a compatibility score of 0.699
# Most compatible user for 'Michael Suarez': 'Kevin Lee' with a compatibility score of 0.710
# Most compatible user for 'Gregory Williams': 'Katherine Owens' with a compatibility score of 0.771
# Most compatible user for 'Miranda Delacruz': 'Edward Brock' with a compatibility score of 0.762
# Most compatible user for 'Robert Brown': 'Alexander Page' with a compatibility score of 0.722
# Most compatible user for 'Mike Gomez': 'Melanie Rivas' with a compatibility score of 0.733
# Most compatible user for 'Grace Perez': 'Sherri Walters' with a compatibility score of 0.731
# Most compatible user for 'Maria Maldonado': 'Scott Hanson' with a compatibility score of 0.719
# Most compatible user for 'Olivia Little': 'Crystal Washington' with a compatibility score of 0.731
# Most compatible user for 'Felicia Jones': 'Alexis Cook' with a compatibility score of 0.752
# Most compatible user for 'Kathryn Miller': 'Pamela Sanchez' with a compatibility score of 0.687
# Most compatible user for 'Sandra Kramer': 'Anthony Jones' with a compatibility score of 0.795
# Most compatible user for 'Erin Snyder': 'Tony Grimes' with a compatibility score of 0.778
# Most compatible user for 'Beth Glenn': 'Jeffrey Wells' with a compatibility score of 0.687
# Most compatible user for 'Lisa Clark': 'Evelyn Rogers' with a compatibility score of 0.754
# Most compatible user for 'Alexis Cook': 'Felicia Jones' with a compatibility score of 0.752
# Most compatible user for 'Amanda Holt': 'Sue Weiss' with a compatibility score of 0.727
# Most compatible user for 'Emily Mcpherson': 'Michael Richmond' with a compatibility score of 0.734
# Most compatible user for 'Meagan Berg': 'Melissa Roth' with a compatibility score of 0.745
# Most compatible user for 'Joshua Green': 'Tamara Brooks' with a compatibility score of 0.730
# Most compatible user for 'Jessica Morales': 'Jaime Saunders' with a compatibility score of 0.731
# Most compatible user for 'Leslie Hernandez': 'Desiree Wright' with a compatibility score of 0.732
# Most compatible user for 'Robin Hampton': 'Monica Geller' with a compatibility score of 0.712
# Most compatible user for 'Denise Hancock': 'Laurie Garcia' with a compatibility score of 0.748
# Most compatible user for 'Latasha Patterson': 'Mandru Luca ' with a compatibility score of 0.742
# Most compatible user for 'Margaret Ray': 'Julia Smith' with a compatibility score of 0.741
# Most compatible user for 'Joyce Harris': 'Robert Gutierrez' with a compatibility score of 0.710
# Most compatible user for 'Scott Castaneda': 'Jonathan Mcintyre' with a compatibility score of 0.730
# Most compatible user for 'Mitchell Love Jr.': 'Matthew Clark' with a compatibility score of 0.713
# Most compatible user for 'Timothy Hammond': 'Caitlyn Hoffman' with a compatibility score of 0.778
# Most compatible user for 'Paul Moon': 'Austin Hancock' with a compatibility score of 0.731
# Most compatible user for 'Erin Davis': 'Felicia Jones' with a compatibility score of 0.745
# Most compatible user for 'Kristin Hensley': 'Joshua Gutierrez' with a compatibility score of 0.699
# Most compatible user for 'Tamara Brooks': 'Joshua Green' with a compatibility score of 0.730
# Most compatible user for 'Erin Riggs': 'Michelle Haynes' with a compatibility score of 0.717
# Most compatible user for 'Alex Brown': 'John Bailey' with a compatibility score of 0.801
# Most compatible user for 'Brooke Ward': 'Claudia Chavez' with a compatibility score of 0.743
# Most compatible user for 'Molly Graham': 'Taylor Thomas' with a compatibility score of 0.743
# Most compatible user for 'Kenneth Rocha': 'Mr. Matthew Bennett' with a compatibility score of 0.757
# Most compatible user for 'Rebecca Fleming': 'Ashley Delacruz' with a compatibility score of 0.753
# Most compatible user for 'Shelly Farmer': 'Sharon Mills' with a compatibility score of 0.745
# Most compatible user for 'Kathy Perry': 'Ian Simon' with a compatibility score of 0.797
# Most compatible user for 'Dan Jimenez': 'Melissa Hill' with a compatibility score of 0.675
# Most compatible user for 'Lisa Smith': 'Louis Perez' with a compatibility score of 0.713
# Most compatible user for 'Deborah Flores': 'Heather Davidson' with a compatibility score of 0.777
# Most compatible user for 'Mary Dennis': 'Steven Schwartz' with a compatibility score of 0.719
# Most compatible user for 'Jill Johnson': 'Ryan Brown' with a compatibility score of 0.769
# Most compatible user for 'Laurie Garcia': 'Denise Hancock' with a compatibility score of 0.748
# Most compatible user for 'Charles Cummings': 'John Nicholson' with a compatibility score of 0.716
# Most compatible user for 'Anthony Jones': 'Sandra Kramer' with a compatibility score of 0.795
# Most compatible user for 'Donna Martin': 'Lisa Norman' with a compatibility score of 0.743
# Most compatible user for 'Corey Green': 'Meagan Berg' with a compatibility score of 0.705
# Most compatible user for 'Whitney Reed': 'Courtney Velasquez' with a compatibility score of 0.748
# Most compatible user for 'Danielle Vaughn DVM': 'Monica Geller' with a compatibility score of 0.669
# Most compatible user for 'Steven Evans': 'Ellen Riley' with a compatibility score of 0.662
# Most compatible user for 'Brooke Jordan': 'Willie Crawford' with a compatibility score of 0.715
# Most compatible user for 'Brooke Ford': 'Steven Cooper' with a compatibility score of 0.721
# Most compatible user for 'Cynthia Smith': 'Christine Nelson' with a compatibility score of 0.669
# Most compatible user for 'Benjamin Willis': 'Nicole Ball' with a compatibility score of 0.792
# Most compatible user for 'Caitlin Williams': 'Edward Brock' with a compatibility score of 0.749
# Most compatible user for 'Cynthia Butler': 'Maria Valdez' with a compatibility score of 0.712
# Most compatible user for 'Shane Harris': 'Scott Hanson' with a compatibility score of 0.758
# Most compatible user for 'Frederick Gordon': 'David Thomas' with a compatibility score of 0.748
# Most compatible user for 'David Washington': 'Jonathan Mitchell' with a compatibility score of 0.806
# Most compatible user for 'James Patrick': 'Daniel Larsen' with a compatibility score of 0.711
# Most compatible user for 'Ryan Brown': 'Jill Johnson' with a compatibility score of 0.769
# Most compatible user for 'Michelle Haynes': 'Catherine Glenn' with a compatibility score of 0.725
# Most compatible user for 'Kendra Sutton': 'Nicholas Myers' with a compatibility score of 0.737
# Most compatible user for 'Katherine Owens': 'Deborah French' with a compatibility score of 0.792
# Most compatible user for 'John Bailey': 'Alex Brown' with a compatibility score of 0.801
# Most compatible user for 'Daniel Larsen': 'Brian Hodges' with a compatibility score of 0.716
# Most compatible user for 'Kelly Ryan': 'Jeremy Ballard' with a compatibility score of 0.754
# Most compatible user for 'Amanda Scott': 'Robert Chapman' with a compatibility score of 0.708
# Most compatible user for 'Mary Potts': 'Ian Wilson' with a compatibility score of 0.792
# Most compatible user for 'Carl Scott': 'Cameron Walls' with a compatibility score of 0.732
# Most compatible user for 'Michael Anderson': 'Leslie Mcclain' with a compatibility score of 0.715
# Most compatible user for 'Richard Burton': 'Paul Warren' with a compatibility score of 0.771
# Most compatible user for 'Jenna Mitchell': 'Brandon Patterson' with a compatibility score of 0.726
# Most compatible user for 'Julia Smith': 'Margaret Ray' with a compatibility score of 0.741
# Most compatible user for 'Daniel Dawson': 'Elizabeth Sanchez' with a compatibility score of 0.782
# Most compatible user for 'Benjamin Ross': 'Andrea Davidson' with a compatibility score of 0.696
# Most compatible user for 'Lindsey Nguyen': 'Wendy Cole' with a compatibility score of 0.694
# Most compatible user for 'Amy Rogers': 'Bobby Gallegos' with a compatibility score of 0.741
# Most compatible user for 'Christine Johnson': 'Benjamin Willis' with a compatibility score of 0.714
# Most compatible user for 'Sarah Hoffman': 'Tonya Miller' with a compatibility score of 0.725
# Most compatible user for 'Hector Norton': 'Garrett Johnson' with a compatibility score of 0.719
# Most compatible user for 'Dr. Amanda Weaver': 'Michael Hayes' with a compatibility score of 0.673
# Most compatible user for 'Eric Williams': 'David Smith' with a compatibility score of 0.744
# Most compatible user for 'David Thomas': 'Frederick Gordon' with a compatibility score of 0.748
# Most compatible user for 'Robert Chapman': 'Amanda Scott' with a compatibility score of 0.708
# Most compatible user for 'Drew Fuentes': 'Heather Costa' with a compatibility score of 0.788
# Most compatible user for 'Jonathan White': 'Christopher Wade' with a compatibility score of 0.690
# Most compatible user for 'Stacie Schultz': 'Tracy Williams' with a compatibility score of 0.719
# Most compatible user for 'David Smith': 'Eric Williams' with a compatibility score of 0.744
# Most compatible user for 'Mr. Lee Ball': 'Micheal White' with a compatibility score of 0.719
# Most compatible user for 'Miguel Stewart': 'Jill Johnson' with a compatibility score of 0.753
# Most compatible user for 'Mrs. Karen Ellis DVM': 'Ian Wilson' with a compatibility score of 0.709
# Most compatible user for 'Susan Rhodes': 'Desiree Wolf' with a compatibility score of 0.700
# Most compatible user for 'Erica Chapman': 'Amanda Scott' with a compatibility score of 0.705
# Most compatible user for 'Rodney Garcia': 'Pamela Proctor' with a compatibility score of 0.749
# Most compatible user for 'Heather Lawrence': 'Frederick Gordon' with a compatibility score of 0.727
# Most compatible user for 'Randall Fox': 'Michael Rubio' with a compatibility score of 0.746
# Most compatible user for 'Lucas Mayer': 'Jennifer Jackson' with a compatibility score of 0.689
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       4 most_compatible_user = similarity_df[user_name].idxmax()
#       5 compatibility_score = similarity_df[user_name].max()
# ----> 6 print(f"Most compatible user for '{user_name}': '{most_compatible_user}' with a compatibility score of {compatibility_score:.3f}")
#
# TypeError: unsupported format string passed to Series.__format__

# %%
# Show the compatibilities for Ana Lipianu with George-Alexandru Marin and Mandru Luca
print(similarity_df['Ana Lipianu']['George-Alexandru Marin'])
print(similarity_df['Ana Lipianu']['Mandru Luca '])
# Out:
# 0.45346179604530334
# 0.5067331790924072

# %%
# Calculate compatibility between Ana Lipianu and Stefan Caraenache
compatibility_score = calculate_similarity(df.iloc[6], df.iloc[517], matching_columns, model)
print(f"Compatibility Score between '{df.iloc[6]['What is your name?']}' and '{df.iloc[517]['What is your name?']}': {compatibility_score:.3f}")

# Print compabilities for Ana Lipianu
print(similarity_df['Ana Lipianu'].sort_values(ascending=False))
# Out:
# Compatibility Score between 'Ana Lipianu' and 'Stefan Caraenache': 0.636
# What is your name?
# Thomas Carr           0.690400
# Cynthia Butler        0.655429
# Jodi Adkins           0.655209
# Jerry Hill            0.648750
# Angelica Velasquez    0.644394
#                         ...
# Dominic Green         0.287915
# Rachel Thompson       0.285889
# Angela Marshall       0.279686
# Richard Nelson        0.278558
# Ana Lipianu           0.000000
# Name: Ana Lipianu, Length: 516, dtype: float64

# %%
# Calculate ccompatibility for Erin $$$ with everyone and keep the 10 most compatible
compatibilities = []
for i in range(num_users):
    compatibility_score = calculate_similarity(df.iloc[518], df.iloc[i], matching_columns, model)
    compatibilities.append((df.iloc[i]['What is your name?'], compatibility_score))

# Sorteaza compatibilitatile si afiseaza primele 10
compatibilities.sort(key=lambda x: x[1], reverse=True)
print(compatibilities[:10])


# for i in range(num_users):
#     compatibility_score = calculate_similarity(df.iloc[518], df.iloc[i], matching_columns, model)
#     print(f"Compatibility Score between '{df.iloc[518]['What is your name?']}' and '{df.iloc[i]['What is your name?']}': {compatibility_score:.3f}")
# Out:
# [('Richard Burton', 0.7942384), ('Ella', 0.76357436), ('Beth Rose', 0.72024035), ('Jesse Boone', 0.70739704), ('Alia Andrei', 0.69294655), ('Ian Simon', 0.6922599), ('Robert Woodard', 0.6921126), ('Daniel Shah', 0.68855274), ('John Bailey', 0.68717164), ('John Allen', 0.68408614)]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:162, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:203, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:211, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:107, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'Erin $$$'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 3
#       1 # print top 10 compatibilities for Erin $$$
#       2 # print(similarity_df['Erin $$$'].sort_values(ascending=False).head(10))
# ----> 3 print(similarity_df[df.iloc[518][1]].sort_values(ascending=False).tail(10))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Erin $$$'
